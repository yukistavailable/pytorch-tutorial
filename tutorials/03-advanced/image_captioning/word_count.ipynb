# %%
import json
from collections import defaultdict

# %%
# with open('data/annotations/captions_val2014.json') as f:
#     val_text = f.read()
# with open('data/annotations/captions_train2014.json') as f:
#     train_text = f.read()
# val_info = json.loads(val_text)
# train_info = json.loads(train_text)

# %%
# total = ''
# for a in train_info['annotations']:
#     total += a['caption'].lower().replace('.', ' ')

# %%
# d = defaultdict(int)
# for word in total.split(' '):
#     if word != '':
#         d[word] += 1

# %%
# with open('train_words_count.json', 'w') as f:
#     json.dump(d, f)

# %% [markdown]
# # sort

# %%
with open('words_count.json', 'r') as f:
    generated_words_count = json.load(f)

with open('val_words_count.json', 'r') as f:
    val_words_count = json.load(f)

with open('train_words_count.json', 'r') as f:
    train_words_count = json.load(f)

# %%
generated_words_count = dict(sorted(generated_words_count.items(), key=lambda item: - item[1]))
val_words_count = dict(sorted(val_words_count.items(), key=lambda item: - item[1]))
train_words_count = dict(sorted(train_words_count.items(), key=lambda item: - item[1]))

# %%
total_generated = sum(generated_words_count.values())
total_train = sum(train_words_count.values())
total_val = sum(val_words_count.values())
generated_ratio = generated_words_count / total_generated
train_ratio = 
val_ratio =

# %%
generated_ratio = generated_words_count / total_generated
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 generated_ratio = generated_words_count / total_generated
#
# TypeError: unsupported operand type(s) for /: 'dict' and 'int'

# %%
total_val
# Out:
# 2076748

# %%
total_generated
# Out:
# 436784

# %% [markdown]
# # show graph

# %%
val_words_count
# Out:
# {'a': 306730,
#  'on': 73901,
#  'of': 69917,
#  'the': 66334,
#  'in': 62714,
#  'with': 53506,
#  'and': 47850,
#  'is': 33715,
#  'man': 24329,
#  'to': 23424,
#  'sitting': 18350,
#  'an': 15631,
#  'at': 14654,
#  'standing': 14204,
#  'two': 14055,
#  'are': 13958,
#  'people': 13415,
#  'next': 12952,
#  'white': 12169,
#  'woman': 11165,
#  'holding': 9664,
#  'that': 9634,
#  'street': 9460,
#  'table': 9005,
#  'large': 8257,
#  'person': 8135,
#  'some': 7842,
#  'top': 7488,
#  'down': 7460,
#  'group': 7220,
#  'up': 7178,
#  'it': 7062,
#  'tennis': 6766,
#  'front': 6742,
#  'near': 6706,
#  'his': 6617,
#  'small': 6615,
#  'black': 6589,
#  'train': 6570,
#  'riding': 6163,
#  'cat': 6112,
#  'field': 6099,
#  'dog': 6026,
#  'red': 5829,
#  'young': 5750,
#  'plate': 5744,
#  'by': 5676,
#  'room': 5669,
#  'has': 5296,
#  'playing': 5074,
#  'while': 4841,
#  'walking': 4832,
#  'baseball': 4816,
#  'water': 4814,
#  'sign': 4714,
#  'bathroom': 4684,
#  'blue': 4616,
#  'green': 4333,
#  'kitchen': 4299,
#  'side': 4291,
#  'parked': 4272,
#  'bus': 4227,
#  'building': 4171,
#  'food': 4141,
#  'pizza': 4087,
#  'looking': 4046,
#  'other': 4038,
#  'clock': 3990,
#  'grass': 3897,
#  'for': 3784,
#  'bed': 3756,
#  'couple': 3663,
#  'snow': 3561,
#  'boy': 3501,
#  'beach': 3449,
#  'city': 3426,
#  'wearing': 3423,
#  'there': 3412,
#  'men': 3343,
#  'over': 3339,
#  'toilet': 3327,
#  'her': 3312,
#  'sits': 3265,
#  'out': 3263,
#  'flying': 3257,
#  'ball': 3238,
#  'player': 3230,
#  'from': 3204,
#  'road': 3192,
#  'three': 3168,
#  'laying': 3126,
#  'girl': 3117,
#  'wooden': 3022,
#  'picture': 3006,
#  'bench': 2987,
#  'skateboard': 2927,
#  'brown': 2891,
#  'through': 2883,
#  'their': 2882,
#  'several': 2879,
#  'game': 2867,
#  'yellow': 2855,
#  'one': 2836,
#  'bear': 2834,
#  'horse': 2799,
#  'computer': 2762,
#  'area': 2761,
#  'eating': 2743,
#  'laptop': 2728,
#  'around': 2689,
#  'as': 2623,
#  'giraffe': 2603,
#  'frisbee': 2551,
#  'phone': 2550,
#  'cake': 2530,
#  'motorcycle': 2475,
#  'living': 2465,
#  'outside': 2460,
#  'board': 2413,
#  'each': 2393,
#  'covered': 2375,
#  'desk': 2336,
#  'truck': 2329,
#  'very': 2323,
#  'under': 2323,
#  'open': 2321,
#  'behind': 2289,
#  'close': 2284,
#  'filled': 2278,
#  'elephant': 2252,
#  'umbrella': 2245,
#  'many': 2229,
#  'little': 2221,
#  'tree': 2214,
#  'wall': 2206,
#  'car': 2188,
#  'old': 2181,
#  'window': 2179,
#  'air': 2148,
#  'stop': 2148,
#  'sink': 2143,
#  'fire': 2110,
#  'park': 2097,
#  'its': 2083,
#  'surfboard': 2019,
#  'into': 1990,
#  'trees': 1947,
#  'court': 1935,
#  'child': 1928,
#  'this': 1913,
#  'inside': 1893,
#  'bunch': 1890,
#  'bird': 1870,
#  'big': 1870,
#  'stands': 1867,
#  'view': 1856,
#  'boat': 1852,
#  'kite': 1836,
#  'cell': 1835,
#  'light': 1832,
#  'together': 1805,
#  'back': 1803,
#  'glass': 1797,
#  'sheep': 1764,
#  'skis': 1762,
#  'chair': 1758,
#  'orange': 1730,
#  'traffic': 1727,
#  'different': 1722,
#  'sky': 1712,
#  'tower': 1709,
#  'zebra': 1692,
#  'parking': 1676,
#  'bowl': 1674,
#  'teddy': 1668,
#  'photo': 1665,
#  'ocean': 1662,
#  'shirt': 1657,
#  'hydrant': 1639,
#  'hand': 1631,
#  'tall': 1624,
#  'bat': 1597,
#  'sidewalk': 1592,
#  'sandwich': 1586,
#  'women': 1559,
#  'another': 1548,
#  'stand': 1548,
#  'lot': 1544,
#  'counter': 1530,
#  'background': 1521,
#  'mirror': 1518,
#  'flowers': 1513,
#  'vase': 1507,
#  'zebras': 1501,
#  'wave': 1499,
#  'couch': 1492,
#  'fence': 1489,
#  'grassy': 1481,
#  'baby': 1474,
#  'floor': 1472,
#  'cars': 1462,
#  'giraffes': 1452,
#  'tracks': 1442,
#  'taking': 1430,
#  'along': 1425,
#  'horses': 1419,
#  'being': 1415,
#  'full': 1410,
#  'elephants': 1385,
#  'airplane': 1384,
#  'off': 1375,
#  'middle': 1374,
#  'vegetables': 1367,
#  'tie': 1366,
#  'racket': 1361,
#  'image': 1343,
#  'ground': 1335,
#  'ready': 1322,
#  'sit': 1321,
#  'plane': 1311,
#  'signs': 1255,
#  'station': 1244,
#  'piece': 1243,
#  'long': 1241,
#  'stuffed': 1223,
#  'driving': 1222,
#  'above': 1217,
#  'head': 1213,
#  'grazing': 1206,
#  'hanging': 1204,
#  'beside': 1198,
#  'bike': 1197,
#  'four': 1197,
#  'across': 1196,
#  'luggage': 1196,
#  'day': 1190,
#  'bananas': 1182,
#  'dirt': 1182,
#  'dogs': 1181,
#  'hot': 1162,
#  'snowy': 1155,
#  'holds': 1155,
#  'cows': 1145,
#  'children': 1125,
#  'hill': 1104,
#  'doing': 1102,
#  'pink': 1090,
#  'wine': 1087,
#  'skiing': 1085,
#  'looks': 1078,
#  'during': 1076,
#  'herd': 1072,
#  'empty': 1070,
#  'camera': 1054,
#  'pole': 1053,
#  'ski': 1052,
#  'watching': 1050,
#  'soccer': 1050,
#  'glasses': 1044,
#  'wii': 1044,
#  'slope': 1043,
#  'suit': 1041,
#  'broccoli': 1036,
#  'going': 1030,
#  'cow': 1029,
#  'mountain': 1029,
#  'traveling': 1022,
#  'hat': 1016,
#  'refrigerator': 1007,
#  'ita': 1001,
#  'display': 1000,
#  'skate': 998,
#  'pair': 997,
#  'jumping': 993,
#  'smiling': 992,
#  'brick': 991,
#  'them': 988,
#  'umbrellas': 984,
#  'boats': 983,
#  'surf': 978,
#  'birds': 977,
#  'using': 974,
#  'corner': 968,
#  'video': 967,
#  'buildings': 965,
#  'posing': 965,
#  'cutting': 964,
#  'fruit': 962,
#  'track': 961,
#  'crowd': 960,
#  'against': 945,
#  'body': 940,
#  'colorful': 939,
#  'topped': 934,
#  'getting': 925,
#  'oven': 923,
#  'trick': 918,
#  'who': 918,
#  'set': 914,
#  'door': 910,
#  'stove': 904,
#  'paper': 904,
#  'box': 903,
#  'lady': 899,
#  'carrying': 893,
#  'various': 890,
#  'television': 881,
#  'all': 880,
#  'keyboard': 879,
#  'guy': 878,
#  'cup': 878,
#  'animals': 869,
#  'hit': 853,
#  'talking': 848,
#  'swinging': 844,
#  'tv': 843,
#  'bears': 834,
#  'waiting': 832,
#  "it's": 830,
#  'lots': 829,
#  'chairs': 828,
#  'plates': 828,
#  'something': 825,
#  'motorcycles': 824,
#  'metal': 823,
#  'racquet': 816,
#  'remote': 814,
#  'be': 809,
#  'face': 806,
#  'river': 805,
#  'running': 805,
#  'bedroom': 804,
#  'kites': 799,
#  'double': 799,
#  'busy': 798,
#  'coffee': 797,
#  'night': 783,
#  'surfer': 783,
#  'about': 780,
#  'restaurant': 778,
#  'wood': 768,
#  'skier': 768,
#  'lying': 754,
#  'intersection': 749,
#  'airport': 749,
#  'bicycle': 746,
#  'line': 742,
#  'lights': 737,
#  'walk': 736,
#  'players': 734,
#  'banana': 732,
#  'items': 731,
#  'like': 731,
#  'sleeping': 728,
#  'dressed': 727,
#  'high': 726,
#  'surfing': 720,
#  'tray': 720,
#  'male': 708,
#  'cheese': 708,
#  'home': 704,
#  'shower': 703,
#  'passenger': 697,
#  'shown': 695,
#  'skateboarder': 680,
#  'house': 675,
#  'snowboard': 672,
#  'kids': 661,
#  'half': 658,
#  'made': 658,
#  'look': 656,
#  'store': 655,
#  'gray': 650,
#  'suitcase': 650,
#  'bridge': 650,
#  'colored': 647,
#  'cut': 645,
#  'between': 644,
#  'rides': 641,
#  'he': 641,
#  'showing': 639,
#  'hands': 638,
#  'donuts': 636,
#  'adult': 635,
#  'someone': 632,
#  'slice': 632,
#  'screen': 630,
#  'bottle': 628,
#  'toy': 627,
#  'row': 625,
#  'pulling': 623,
#  'meat': 623,
#  'surrounded': 617,
#  'jet': 614,
#  'number': 611,
#  'dark': 608,
#  'ramp': 607,
#  'mouth': 602,
#  'hair': 600,
#  'few': 598,
#  'tablea': 598,
#  'bag': 595,
#  'preparing': 594,
#  'him': 592,
#  'pile': 592,
#  'boys': 591,
#  'decorated': 590,
#  'animal': 589,
#  'batter': 587,
#  'play': 586,
#  'book': 583,
#  'lined': 580,
#  'outdoor': 578,
#  'sand': 577,
#  'scissors': 576,
#  'past': 575,
#  'seat': 569,
#  'silver': 566,
#  'have': 565,
#  'fielda': 561,
#  'way': 560,
#  'girls': 559,
#  'coming': 556,
#  'zoo': 554,
#  'grey': 548,
#  'runway': 546,
#  'painted': 545,
#  'streeta': 545,
#  'older': 544,
#  'kid': 542,
#  'skiers': 538,
#  'walks': 537,
#  'forest': 536,
#  'jacket': 535,
#  'purple': 534,
#  'displayed': 533,
#  'knife': 530,
#  'enclosure': 530,
#  'lake': 529,
#  'stone': 529,
#  'buses': 527,
#  'public': 521,
#  'attached': 519,
#  'tub': 516,
#  'pan': 515,
#  'meal': 514,
#  'mouse': 512,
#  'microwave': 512,
#  'decker': 511,
#  'cloudy': 510,
#  'drink': 508,
#  'furniture': 507,
#  'leaning': 504,
#  'throwing': 504,
#  'waves': 504,
#  'making': 502,
#  'swing': 495,
#  'cross': 493,
#  'birthday': 493,
#  'cabinets': 492,
#  'stopped': 492,
#  'onto': 492,
#  'bread': 492,
#  'scene': 489,
#  'towards': 489,
#  'dining': 483,
#  'lit': 481,
#  'chocolate': 480,
#  'watera': 479,
#  'lush': 478,
#  'hitting': 475,
#  'meter': 472,
#  'crossing': 470,
#  'dish': 466,
#  'resting': 466,
#  'fork': 466,
#  'edge': 464,
#  'statue': 463,
#  'seen': 463,
#  'sunny': 461,
#  'clear': 459,
#  'oranges': 459,
#  'shelf': 458,
#  'photograph': 458,
#  'cats': 458,
#  'clean': 455,
#  'moving': 454,
#  'no': 451,
#  'can': 451,
#  'female': 446,
#  'bright': 444,
#  'surfboards': 444,
#  'office': 441,
#  'perched': 439,
#  'ride': 439,
#  'been': 437,
#  'windows': 435,
#  'drinking': 434,
#  'monitor': 433,
#  'dress': 430,
#  'flower': 429,
#  'rocks': 429,
#  'walls': 426,
#  'branch': 426,
#  'market': 426,
#  'beautiful': 422,
#  'motor': 421,
#  'bikes': 420,
#  'underneath': 420,
#  'sun': 418,
#  'tables': 417,
#  'rail': 416,
#  'slices': 416,
#  'wet': 416,
#  'pieces': 415,
#  'placed': 413,
#  'plastic': 413,
#  'carrots': 411,
#  'watch': 410,
#  'catch': 409,
#  'blanket': 408,
#  'salad': 408,
#  'rain': 406,
#  'bath': 405,
#  'pictures': 404,
#  'setting': 403,
#  'trying': 403,
#  'shows': 399,
#  'working': 398,
#  'hotel': 397,
#  'platform': 397,
#  'beer': 397,
#  'country': 393,
#  'cooking': 393,
#  'basket': 391,
#  'shot': 387,
#  'helmet': 387,
#  'nice': 387,
#  'cart': 386,
#  'or': 385,
#  'rock': 385,
#  'passing': 385,
#  'leaves': 385,
#  'controller': 385,
#  'modern': 384,
#  'trains': 384,
#  'eat': 383,
#  'donut': 382,
#  'computers': 381,
#  'tiled': 381,
#  'mountains': 381,
#  'time': 379,
#  'fruits': 378,
#  'snowboarder': 378,
#  'multiple': 377,
#  'yard': 376,
#  'sink,': 375,
#  'having': 375,
#  'case': 375,
#  'shore': 373,
#  'types': 370,
#  'graffiti': 368,
#  'teeth': 367,
#  'sandy': 367,
#  'books': 365,
#  'they': 363,
#  'fries': 363,
#  'pizzas': 363,
#  'benches': 361,
#  'mounted': 360,
#  'uniform': 360,
#  'plants': 359,
#  'apples': 356,
#  'apple': 354,
#  'nintendo': 354,
#  'fresh': 353,
#  'backgrounda': 353,
#  'lap': 351,
#  'post': 351,
#  'variety': 350,
#  'pitcher': 348,
#  'dinner': 347,
#  'engine': 345,
#  'others': 344,
#  'skateboarding': 344,
#  'family': 344,
#  'containing': 343,
#  'brushing': 343,
#  'just': 342,
#  'balla': 342,
#  'shoes': 341,
#  'pitch': 341,
#  'catcher': 340,
#  'pot': 338,
#  'eaten': 338,
#  'single': 337,
#  'laptops': 337,
#  'polar': 337,
#  'takes': 334,
#  'reading': 333,
#  'vehicle': 330,
#  'plant': 330,
#  'toppings': 329,
#  'watches': 328,
#  'enjoying': 327,
#  'tile': 326,
#  'cute': 324,
#  'path': 324,
#  'left': 322,
#  'gathered': 322,
#  'vases': 321,
#  'gear': 320,
#  'bottles': 319,
#  'including': 318,
#  'steel': 317,
#  'doughnuts': 317,
#  'guys': 317,
#  'pretty': 317,
#  'flies': 316,
#  'trucks': 316,
#  'dry': 316,
#  'toilet,': 315,
#  'end': 315,
#  'doughnut': 311,
#  'control': 310,
#  'performing': 310,
#  'where': 309,
#  'fenced': 308,
#  'curb': 307,
#  'cellphone': 306,
#  'toothbrush': 305,
#  'catching': 304,
#  'carriage': 304,
#  'base': 303,
#  'bowls': 302,
#  'boards': 302,
#  'striped': 301,
#  'appliances': 300,
#  'neck': 300,
#  'shaped': 299,
#  'railroad': 298,
#  '\na': 297,
#  'concrete': 297,
#  'take': 297,
#  'passengers': 297,
#  'after': 296,
#  'jump': 295,
#  'surface': 295,
#  'dock': 293,
#  'dirty': 292,
#  'asian': 292,
#  'school': 292,
#  'surfers': 292,
#  'vehicles': 291,
#  'she': 291,
#  'phones': 291,
#  'woods': 290,
#  'place': 290,
#  'candles': 290,
#  'buildinga': 289,
#  'tricks': 287,
#  'lamp': 287,
#  'cattle': 287,
#  'chicken': 287,
#  'below': 286,
#  'flat': 285,
#  'rack': 285,
#  'bags': 285,
#  'reaching': 285,
#  'container': 284,
#  'smiles': 284,
#  'bathtub': 284,
#  'huge': 283,
#  'fly': 283,
#  'pulled': 283,
#  'treesa': 282,
#  'pillows': 282,
#  'beacha': 281,
#  'right': 280,
#  'match': 280,
#  'town': 279,
#  'crowded': 278,
#  'bicycles': 278,
#  'sticking': 278,
#  'prepares': 278,
#  'feeding': 277,
#  'alone': 276,
#  'giant': 276,
#  'suitcases': 276,
#  'church': 275,
#  'poses': 275,
#  'brush': 274,
#  'distance': 273,
#  'plays': 272,
#  'lays': 272,
#  'floating': 271,
#  'both': 271,
#  'boxes': 271,
#  'pasture': 270,
#  'not': 270,
#  'serve': 269,
#  'platea': 268,
#  'pen': 266,
#  'putting': 266,
#  'taken': 265,
#  'equipment': 263,
#  'bar': 263,
#  'serving': 262,
#  'wedding': 261,
#  'style': 260,
#  'served': 260,
#  'swimming': 260,
#  'reflection': 259,
#  'arm': 259,
#  'shop': 258,
#  'rooma': 258,
#  'staring': 258,
#  'flag': 258,
#  'skateboards': 258,
#  'roada': 257,
#  'grassa': 257,
#  'vintage': 256,
#  'atop': 255,
#  'nearby': 255,
#  'poles': 255,
#  'trunk': 254,
#  'sinks': 253,
#  'well': 253,
#  'hay': 252,
#  'sauce': 252,
#  'kitten': 251,
#  'which': 251,
#  'pillow': 250,
#  'legs': 250,
#  'professional': 250,
#  'away': 249,
#  'stacked': 249,
#  'sliced': 249,
#  'painting': 247,
#  'beds': 247,
#  'toward': 246,
#  'same': 246,
#  'seated': 245,
#  'flock': 244,
#  'dishes': 244,
#  'police': 244,
#  'feet': 242,
#  'breakfast': 242,
#  'towel': 241,
#  'planes': 241,
#  'center': 241,
#  'round': 240,
#  'drinks': 239,
#  'christmas': 239,
#  'cement': 238,
#  'run': 238,
#  'french': 238,
#  'sandwiches': 238,
#  'five': 238,
#  'stall': 237,
#  'fireplace': 237,
#  'show': 237,
#  'docked': 237,
#  'fridge': 237,
#  'spoon': 236,
#  'work': 236,
#  'sofa': 236,
#  'picnic': 235,
#  'throw': 234,
#  'commercial': 233,
#  'wild': 233,
#  'doors': 233,
#  'square': 232,
#  'pointing': 232,
#  'cooked': 232,
#  'airplanes': 231,
#  'get': 230,
#  'subway': 230,
#  'tarmac': 230,
#  'cream': 230,
#  'desktop': 230,
#  'clocks': 229,
#  'cluttered': 228,
#  'shorts': 228,
#  'adults': 226,
#  'trail': 226,
#  'go': 226,
#  'hotdog': 226,
#  'pose': 225,
#  'facing': 225,
#  'ice': 224,
#  'space': 223,
#  'see': 223,
#  'backpack': 223,
#  'pool': 223,
#  'stainless': 221,
#  'wire': 221,
#  'rocky': 221,
#  'foot': 220,
#  'trash': 219,
#  'restroom': 217,
#  'van': 217,
#  'among': 217,
#  'cabinet': 216,
#  'assortment': 216,
#  'swings': 216,
#  'blender': 214,
#  'foods': 214,
#  'eyes': 214,
#  'race': 213,
#  'bushes': 213,
#  'garden': 213,
#  'umpire': 213,
#  'wooded': 212,
#  'desert': 212,
#  'boarding': 211,
#  'clothes': 210,
#  'arranged': 207,
#  'controllers': 207,
#  'narrow': 206,
#  'mother': 206,
#  'soup': 205,
#  'business': 205,
#  'features': 204,
#  'table,': 204,
#  'rice': 203,
#  'ceiling': 203,
#  'overlooking': 202,
#  'rug': 202,
#  'lone': 202,
#  'does': 200,
#  'bottom': 200,
#  'highway': 200,
#  'mid': 199,
#  'skies': 199,
#  'jumps': 199,
#  'pond': 199,
#  'fancy': 198,
#  'sunglasses': 198,
#  'drives': 198,
#  'colors': 198,
#  'games': 198,
#  'bun': 198,
#  'courta': 198,
#  'assorted': 197,
#  'snowa': 197,
#  'potatoes': 197,
#  'before': 196,
#  'gold': 196,
#  'beda': 196,
#  'team': 194,
#  'closeup': 194,
#  'electronic': 194,
#  'leather': 193,
#  'appears': 193,
#  'vegetable': 193,
#  'says': 193,
#  'tied': 193,
#  'construction': 193,
#  'coat': 193,
#  'reads': 193,
#  'couch,': 193,
#  'broccoli,': 193,
#  'urinals': 192,
#  'gamea': 191,
#  'cage': 191,
#  'drawn': 191,
#  'dessert': 190,
#  'roof': 190,
#  'commuter': 189,
#  'paddle': 189,
#  'hillside': 189,
#  'messy': 188,
#  'object': 188,
#  'walla': 188,
#  'ledge': 188,
#  'outdoors': 188,
#  'palm': 187,
#  'things': 186,
#  'hold': 186,
#  'type': 185,
#  'turn': 185,
#  'boarder': 185,
#  'low': 185,
#  'graze': 184,
#  'steps': 184,
#  'overhead': 184,
#  'make': 184,
#  'boarda': 184,
#  'pots': 183,
#  'himself': 183,
#  'kneeling': 183,
#  'new': 182,
#  'transit': 182,
#  'curtain': 181,
#  'monitors': 181,
#  'shelves': 181,
#  'racing': 181,
#  'was': 181,
#  'wetsuit': 181,
#  'ties': 181,
#  'kind': 180,
#  'friends': 180,
#  'windowa': 180,
#  'eats': 179,
#  'what': 179,
#  'tan': 178,
#  'partially': 178,
#  'suits': 178,
#  'rider': 177,
#  'ship': 177,
#  'skya': 176,
#  'short': 176,
#  'harbor': 176,
#  'closed': 175,
#  'rests': 175,
#  'bite': 175,
#  'tomatoes': 175,
#  'lunch': 175,
#  'sides': 174,
#  'pasta': 174,
#  'broken': 173,
#  'rest': 173,
#  'cups': 171,
#  'lies': 171,
#  'pastry': 171,
#  'glove': 171,
#  'wide': 170,
#  'toddler': 169,
#  'blurry': 169,
#  'action': 169,
#  'parka': 168,
#  'held': 168,
#  'plain': 167,
#  'fish': 167,
#  'includes': 167,
#  'bed,': 167,
#  'shade': 167,
#  'carrot': 167,
#  'decorative': 166,
#  'event': 166,
#  'snowboarding': 166,
#  'frisbeea': 166,
#  'military': 165,
#  'smart': 164,
#  'gate': 164,
#  'outfit': 164,
#  'beneath': 163,
#  'turned': 163,
#  'clouds': 163,
#  'areaa': 163,
#  'land': 162,
#  'makes': 162,
#  'model': 161,
#  'rural': 161,
#  'used': 161,
#  'pants': 161,
#  'loaded': 161,
#  'scooter': 160,
#  'bow': 160,
#  'part': 159,
#  'veggies': 159,
#  'party': 159,
#  'stairs': 158,
#  'pans': 158,
#  'walkway': 158,
#  'arms': 158,
#  'outsidea': 157,
#  'photos': 157,
#  'machine': 157,
#  'fencea': 157,
#  'hole': 157,
#  'still': 157,
#  'umbrellaa': 157,
#  'urban': 156,
#  'baked': 156,
#  'bride': 156,
#  'couches': 155,
#  'sale': 155,
#  'kinds': 155,
#  'landing': 154,
#  'heads': 154,
#  'doll': 154,
#  'phonea': 154,
#  'lawn': 154,
#  'cloth': 154,
#  'clothing': 154,
#  'net': 154,
#  'wheel': 153,
#  'farm': 153,
#  'but': 153,
#  'island': 153,
#  'meters': 153,
#  'foreground': 153,
#  'antique': 151,
#  'treea': 151,
#  'fooda': 151,
#  'pie': 151,
#  'sail': 151,
#  'contains': 150,
#  ...}

# %%
train_words_count
# Out:
# {'a': 626455,
#  'on': 150325,
#  'of': 142749,
#  'the': 134183,
#  'in': 128829,
#  'with': 107694,
#  'and': 98722,
#  'is': 68655,
#  'man': 50602,
#  'to': 47721,
#  'sitting': 36783,
#  'an': 32189,
#  'standing': 29990,
#  'at': 29826,
#  'two': 29229,
#  'are': 28802,
#  'people': 28335,
#  'next': 25914,
#  'white': 25038,
#  'woman': 23670,
#  'that': 19497,
#  'holding': 19427,
#  'street': 19172,
#  'table': 19001,
#  'person': 16985,
#  'large': 16827,
#  'down': 16267,
#  'some': 16137,
#  'group': 15077,
#  'top': 15029,
#  'up': 14332,
#  'small': 13808,
#  'it': 13740,
#  'near': 13709,
#  'his': 13596,
#  'front': 13408,
#  'tennis': 13382,
#  'black': 13085,
#  'field': 12858,
#  'riding': 12667,
#  'train': 12468,
#  'dog': 12212,
#  'plate': 12119,
#  'room': 11951,
#  'young': 11759,
#  'by': 11739,
#  'red': 11709,
#  'cat': 11525,
#  'baseball': 11134,
#  'has': 10520,
#  'while': 10430,
#  'walking': 10265,
#  'playing': 10231,
#  'water': 9956,
#  'bathroom': 9589,
#  'blue': 9393,
#  'sign': 9274,
#  'kitchen': 8792,
#  'food': 8744,
#  'parked': 8732,
#  'bus': 8694,
#  'green': 8579,
#  'side': 8279,
#  'looking': 8267,
#  'grass': 8265,
#  'pizza': 8231,
#  'other': 8103,
#  'couple': 7815,
#  'snow': 7661,
#  'boy': 7656,
#  'for': 7640,
#  'building': 7482,
#  'men': 7464,
#  'bed': 7425,
#  'flying': 7264,
#  'beach': 6998,
#  'wearing': 6934,
#  'ball': 6893,
#  'her': 6859,
#  'city': 6852,
#  'out': 6846,
#  'player': 6833,
#  'there': 6769,
#  'clock': 6659,
#  'three': 6646,
#  'over': 6644,
#  'skateboard': 6601,
#  'laying': 6599,
#  'from': 6527,
#  'girl': 6469,
#  'sits': 6422,
#  'toilet': 6322,
#  'wooden': 6316,
#  'road': 6284,
#  'game': 6161,
#  'their': 6115,
#  'through': 6071,
#  'bear': 5951,
#  'around': 5921,
#  'picture': 5907,
#  'eating': 5899,
#  'one': 5849,
#  'several': 5805,
#  'yellow': 5703,
#  'brown': 5701,
#  'bench': 5631,
#  'area': 5528,
#  'horse': 5524,
#  'giraffe': 5452,
#  'cake': 5442,
#  'living': 5424,
#  'laptop': 5410,
#  'as': 5351,
#  'computer': 5236,
#  'frisbee': 5080,
#  'board': 5066,
#  'truck': 5040,
#  'outside': 4955,
#  'phone': 4934,
#  'air': 4923,
#  'covered': 4866,
#  'each': 4864,
#  'open': 4743,
#  'close': 4742,
#  'motorcycle': 4693,
#  'very': 4651,
#  'desk': 4625,
#  'behind': 4621,
#  'elephant': 4584,
#  'car': 4559,
#  'window': 4539,
#  'old': 4504,
#  'filled': 4497,
#  'little': 4479,
#  'many': 4477,
#  'under': 4476,
#  'fire': 4446,
#  'umbrella': 4434,
#  'sink': 4415,
#  'into': 4342,
#  'tree': 4317,
#  'stop': 4275,
#  'park': 4239,
#  'wall': 4237,
#  'trees': 4153,
#  'child': 4104,
#  'its': 4076,
#  'this': 3893,
#  'kite': 3885,
#  'inside': 3869,
#  'stands': 3848,
#  'photo': 3825,
#  'big': 3821,
#  'skis': 3819,
#  'airplane': 3799,
#  'court': 3793,
#  'sheep': 3780,
#  'together': 3778,
#  'bat': 3767,
#  'bunch': 3765,
#  'surfboard': 3757,
#  'bowl': 3754,
#  'sky': 3749,
#  'boat': 3701,
#  'back': 3699,
#  'cell': 3675,
#  'view': 3667,
#  'bird': 3597,
#  'teddy': 3568,
#  'glass': 3538,
#  'traffic': 3513,
#  'light': 3497,
#  'zebra': 3497,
#  'plane': 3473,
#  'women': 3458,
#  'hydrant': 3453,
#  'another': 3415,
#  'shirt': 3334,
#  'different': 3326,
#  'ocean': 3319,
#  'orange': 3311,
#  'chair': 3263,
#  'counter': 3239,
#  'tall': 3208,
#  'sandwich': 3207,
#  'couch': 3181,
#  'giraffes': 3181,
#  'horses': 3180,
#  'stand': 3172,
#  'parking': 3147,
#  'baby': 3090,
#  'being': 3068,
#  'fence': 3064,
#  'vase': 3062,
#  'hand': 3058,
#  'lot': 3046,
#  'sidewalk': 3042,
#  'grassy': 3014,
#  'mirror': 3002,
#  'flowers': 2993,
#  'background': 2980,
#  'wave': 2966,
#  'off': 2921,
#  'full': 2877,
#  'along': 2872,
#  'elephants': 2872,
#  'cars': 2858,
#  'floor': 2854,
#  'tracks': 2836,
#  'ready': 2831,
#  'zebras': 2821,
#  'tower': 2819,
#  'middle': 2817,
#  'image': 2777,
#  'racket': 2771,
#  'dirt': 2760,
#  'vegetables': 2717,
#  'sit': 2715,
#  'ground': 2694,
#  'driving': 2692,
#  'stuffed': 2657,
#  'taking': 2646,
#  'tie': 2632,
#  'bananas': 2613,
#  'bike': 2569,
#  'piece': 2552,
#  'skate': 2524,
#  'across': 2521,
#  'skiing': 2519,
#  'beside': 2509,
#  'signs': 2496,
#  'above': 2487,
#  'grazing': 2475,
#  'day': 2474,
#  'during': 2440,
#  'snowy': 2431,
#  'cows': 2412,
#  'wine': 2403,
#  'head': 2377,
#  'long': 2374,
#  'hill': 2366,
#  'slope': 2363,
#  'station': 2341,
#  'luggage': 2329,
#  'doing': 2326,
#  'holds': 2321,
#  'hanging': 2309,
#  'pink': 2285,
#  'four': 2266,
#  'hat': 2251,
#  'herd': 2250,
#  'wii': 2249,
#  'suit': 2223,
#  'ski': 2209,
#  'cutting': 2208,
#  'display': 2196,
#  'hot': 2193,
#  'going': 2177,
#  'double': 2173,
#  'cow': 2166,
#  'glasses': 2147,
#  'pair': 2124,
#  'refrigerator': 2118,
#  'talking': 2116,
#  'jumping': 2107,
#  'swinging': 2094,
#  'kites': 2093,
#  'empty': 2092,
#  'mountain': 2091,
#  'children': 2085,
#  'looks': 2078,
#  'fruit': 2073,
#  'corner': 2036,
#  'posing': 2027,
#  'watching': 2019,
#  'ita': 2019,
#  'them': 2006,
#  'video': 1985,
#  'trick': 1977,
#  'topped': 1976,
#  'traveling': 1958,
#  'getting': 1948,
#  'colorful': 1944,
#  'pole': 1937,
#  'boats': 1930,
#  'smiling': 1928,
#  'camera': 1922,
#  'soccer': 1913,
#  'crowd': 1907,
#  'using': 1896,
#  'various': 1890,
#  'animals': 1881,
#  'hit': 1880,
#  'buildings': 1877,
#  'surf': 1876,
#  'broccoli': 1876,
#  'who': 1874,
#  'umbrellas': 1868,
#  'lady': 1865,
#  'airport': 1860,
#  'door': 1847,
#  'body': 1846,
#  'box': 1846,
#  'against': 1829,
#  'television': 1823,
#  'birds': 1822,
#  'all': 1821,
#  'oven': 1811,
#  'wood': 1798,
#  'set': 1790,
#  'track': 1773,
#  'chairs': 1770,
#  'plates': 1768,
#  'lots': 1767,
#  'carrying': 1763,
#  'keyboard': 1741,
#  'coffee': 1717,
#  'dogs': 1716,
#  'guy': 1716,
#  'be': 1713,
#  'players': 1696,
#  "it's": 1690,
#  'skateboarder': 1690,
#  'waiting': 1686,
#  'stove': 1683,
#  'motorcycles': 1674,
#  'tv': 1672,
#  'brick': 1661,
#  'banana': 1660,
#  'jet': 1644,
#  'bedroom': 1643,
#  'paper': 1630,
#  'metal': 1627,
#  'bears': 1620,
#  'about': 1605,
#  'walk': 1599,
#  'something': 1588,
#  'cup': 1582,
#  'decker': 1577,
#  'skier': 1575,
#  'snowboard': 1570,
#  'high': 1564,
#  'home': 1553,
#  'restaurant': 1539,
#  'bicycle': 1537,
#  'passenger': 1537,
#  'running': 1536,
#  'racquet': 1534,
#  'lights': 1518,
#  'remote': 1510,
#  'surfer': 1507,
#  'runway': 1507,
#  'river': 1504,
#  'busy': 1503,
#  'lying': 1498,
#  'cheese': 1482,
#  'house': 1478,
#  'male': 1477,
#  'items': 1474,
#  'dressed': 1473,
#  'night': 1472,
#  'preparing': 1470,
#  'line': 1455,
#  'slice': 1443,
#  'face': 1439,
#  'like': 1429,
#  'ramp': 1414,
#  'he': 1409,
#  'rides': 1400,
#  'pulling': 1400,
#  'hands': 1399,
#  'cut': 1397,
#  'surfing': 1384,
#  'animal': 1383,
#  'shower': 1373,
#  'shown': 1360,
#  'intersection': 1359,
#  'made': 1342,
#  'gray': 1335,
#  'book': 1329,
#  'number': 1327,
#  'someone': 1315,
#  'tablea': 1307,
#  'tray': 1295,
#  'bottle': 1292,
#  'surrounded': 1290,
#  'look': 1278,
#  'suitcase': 1277,
#  'meat': 1272,
#  'sleeping': 1248,
#  'play': 1247,
#  'half': 1243,
#  'screen': 1238,
#  'showing': 1235,
#  'dark': 1234,
#  'row': 1233,
#  'between': 1226,
#  'jacket': 1221,
#  'mouth': 1218,
#  'decorated': 1217,
#  'walks': 1215,
#  'store': 1211,
#  'few': 1206,
#  'lined': 1205,
#  'pile': 1205,
#  'silver': 1200,
#  'colored': 1198,
#  'kids': 1197,
#  'scissors': 1193,
#  'him': 1191,
#  'bag': 1186,
#  'donuts': 1177,
#  'knife': 1174,
#  'older': 1166,
#  'streeta': 1166,
#  'buses': 1158,
#  'toy': 1157,
#  'bridge': 1156,
#  'batter': 1156,
#  'purple': 1154,
#  'meal': 1150,
#  'sand': 1144,
#  'adult': 1144,
#  'fielda': 1142,
#  'enclosure': 1140,
#  'skiers': 1136,
#  'past': 1128,
#  'boys': 1127,
#  'cloudy': 1120,
#  'zoo': 1117,
#  'girls': 1113,
#  'grey': 1103,
#  'throwing': 1101,
#  'forest': 1100,
#  'outdoor': 1099,
#  'photograph': 1099,
#  'kid': 1097,
#  'swing': 1097,
#  'way': 1092,
#  'lake': 1091,
#  'have': 1085,
#  'onto': 1080,
#  'microwave': 1076,
#  'displayed': 1074,
#  'leaning': 1071,
#  'coming': 1068,
#  'attached': 1066,
#  'making': 1062,
#  'dining': 1053,
#  'seat': 1052,
#  'chocolate': 1052,
#  'furniture': 1050,
#  'crossing': 1046,
#  'drinking': 1043,
#  'hitting': 1015,
#  'can': 1013,
#  'seen': 1010,
#  'hair': 1006,
#  'cats': 1004,
#  'lush': 1001,
#  'scene': 997,
#  'oranges': 987,
#  'resting': 982,
#  'waves': 978,
#  'painted': 977,
#  'birthday': 977,
#  'female': 974,
#  'towards': 974,
#  'bread': 973,
#  'lit': 971,
#  'mouse': 970,
#  'stone': 969,
#  'tub': 965,
#  'no': 958,
#  'watera': 956,
#  'office': 950,
#  'catch': 945,
#  'fruits': 945,
#  'cabinets': 943,
#  'plastic': 933,
#  'sunny': 930,
#  'been': 927,
#  'meter': 927,
#  'cross': 926,
#  'drink': 924,
#  'fork': 924,
#  'shelf': 923,
#  'salad': 919,
#  'apple': 918,
#  'carrots': 916,
#  'watch': 915,
#  'snowboarder': 909,
#  'working': 905,
#  'flower': 905,
#  'public': 900,
#  'trying': 897,
#  'bright': 896,
#  'dish': 880,
#  'beautiful': 878,
#  'moving': 878,
#  'pan': 878,
#  'police': 874,
#  'sink,': 872,
#  'setting': 869,
#  'rocks': 868,
#  'stopped': 866,
#  'monitor': 866,
#  'clear': 862,
#  'clean': 861,
#  'uniform': 860,
#  'market': 858,
#  'leaves': 858,
#  'edge': 857,
#  'pictures': 852,
#  'underneath': 845,
#  'having': 843,
#  'blanket': 841,
#  'or': 839,
#  'teeth': 839,
#  'helmet': 838,
#  'bikes': 836,
#  'ride': 829,
#  'skateboarding': 828,
#  'bath': 827,
#  'dress': 825,
#  'donut': 825,
#  'fries': 818,
#  'sun': 816,
#  'shot': 815,
#  'surfboards': 814,
#  'apples': 814,
#  'rain': 813,
#  'walls': 809,
#  'nice': 808,
#  'statue': 807,
#  'tables': 806,
#  'shows': 805,
#  'placed': 802,
#  'slices': 802,
#  'mountains': 801,
#  'windows': 798,
#  'platform': 795,
#  'rail': 793,
#  'sandy': 790,
#  'motor': 787,
#  'passing': 786,
#  'rock': 782,
#  'base': 774,
#  'eat': 774,
#  'brushing': 773,
#  'perched': 769,
#  'country': 766,
#  'just': 765,
#  'family': 764,
#  'pieces': 763,
#  'wet': 761,
#  'time': 760,
#  'books': 758,
#  'controller': 757,
#  'they': 752,
#  'vases': 750,
#  'types': 748,
#  'yard': 745,
#  'dinner': 745,
#  'nintendo': 743,
#  'cooking': 742,
#  'balla': 736,
#  'cart': 735,
#  'reading': 733,
#  'vehicle': 732,
#  'computers': 732,
#  'enjoying': 730,
#  'pitch': 729,
#  'eaten': 727,
#  'tiled': 725,
#  'single': 724,
#  'hotel': 721,
#  'basket': 718,
#  'path': 717,
#  'shore': 712,
#  'doughnut': 709,
#  'trains': 709,
#  'catcher': 707,
#  'others': 706,
#  'performing': 706,
#  'variety': 703,
#  'pizzas': 703,
#  'modern': 702,
#  'guys': 701,
#  'branch': 701,
#  'gathered': 700,
#  'tarmac': 699,
#  'cellphone': 699,
#  'watches': 698,
#  'mounted': 695,
#  'pretty': 695,
#  'engine': 695,
#  'plant': 694,
#  'boards': 693,
#  'town': 681,
#  'cute': 679,
#  '\na': 678,
#  'toilet,': 675,
#  'case': 675,
#  'feeding': 672,
#  'lap': 670,
#  'sauce': 670,
#  'bowls': 669,
#  'pitcher': 665,
#  'trucks': 661,
#  'benches': 661,
#  'doughnuts': 657,
#  'flies': 657,
#  'end': 656,
#  'containing': 654,
#  'toppings': 654,
#  'tricks': 653,
#  'fenced': 651,
#  'railroad': 649,
#  'backgrounda': 647,
#  'fresh': 646,
#  'multiple': 645,
#  'jump': 645,
#  'laptops': 644,
#  'dirty': 642,
#  'gear': 639,
#  'passengers': 635,
#  'take': 633,
#  'candles': 632,
#  'distance': 629,
#  'left': 629,
#  'after': 628,
#  'cattle': 627,
#  'beer': 624,
#  'lamp': 621,
#  'place': 621,
#  'fly': 618,
#  'vintage': 615,
#  'graffiti': 614,
#  'post': 613,
#  'appliances': 612,
#  'plants': 611,
#  'right': 609,
#  'carriage': 609,
#  'school': 609,
#  'below': 608,
#  'shop': 607,
#  'crowded': 607,
#  'pulled': 603,
#  'steel': 599,
#  'phones': 598,
#  'concrete': 598,
#  'poles': 597,
#  'well': 596,
#  'including': 596,
#  'striped': 595,
#  'surface': 591,
#  'beacha': 590,
#  'sliced': 590,
#  'rooma': 588,
#  'planes': 587,
#  'five': 586,
#  'tile': 585,
#  'bathtub': 584,
#  'takes': 584,
#  'huge': 582,
#  'center': 577,
#  'reaching': 577,
#  'pasture': 576,
#  'both': 575,
#  'she': 575,
#  'flat': 573,
#  'toothbrush': 572,
#  'curb': 572,
#  'served': 569,
#  'catching': 569,
#  'sandwiches': 569,
#  'floating': 567,
#  'grassa': 567,
#  'brush': 566,
#  'bar': 564,
#  'bags': 563,
#  'atop': 562,
#  'plays': 560,
#  'woods': 560,
#  'pen': 560,
#  'drinks': 559,
#  'alone': 558,
#  'putting': 556,
#  'neck': 555,
#  'feet': 551,
#  'giant': 551,
#  'skateboards': 551,
#  'shaped': 548,
#  'equipment': 547,
#  'bottles': 547,
#  'arm': 546,
#  'poses': 546,
#  'pose': 546,
#  'dry': 546,
#  'pot': 545,
#  'buildinga': 543,
#  'commercial': 540,
#  'boxes': 540,
#  'polar': 538,
#  'shoes': 537,
#  'control': 536,
#  'sticking': 536,
#  'beds': 536,
#  'trunk': 535,
#  'match': 534,
#  'airplanes': 533,
#  'prepares': 532,
#  'taken': 532,
#  'where': 530,
#  'container': 530,
#  'professional': 527,
#  'staring': 527,
#  'style': 527,
#  'work': 526,
#  'serving': 526,
#  'clothes': 525,
#  'lays': 524,
#  'away': 523,
#  'platea': 523,
#  'dock': 522,
#  'pillows': 522,
#  'lone': 521,
#  'nearby': 520,
#  'smiles': 519,
#  'church': 519,
#  'space': 518,
#  'not': 518,
#  'which': 517,
#  'bicycles': 516,
#  'run': 516,
#  'suitcases': 516,
#  'rice': 516,
#  'vehicles': 514,
#  'fireplace': 514,
#  'dessert': 510,
#  'asian': 509,
#  'mother': 507,
#  'towel': 506,
#  'subway': 505,
#  'cement': 504,
#  'christmas': 504,
#  'stacked': 503,
#  'foods': 503,
#  'rack': 502,
#  'shorts': 497,
#  'wire': 496,
#  'fridge': 496,
#  'surfers': 496,
#  'toward': 496,
#  'cream': 495,
#  'hay': 495,
#  'legs': 493,
#  'breakfast': 493,
#  'swings': 492,
#  'sofa': 490,
#  'treesa': 490,
#  'chicken': 490,
#  'same': 488,
#  'roada': 487,
#  'painting': 486,
#  'cluttered': 485,
#  'dishes': 484,
#  'sinks': 483,
#  'french': 483,
#  'reflection': 481,
#  'round': 479,
#  'drives': 477,
#  'military': 477,
#  'throw': 476,
#  'seated': 472,
#  'serve': 471,
#  'show': 471,
#  'get': 469,
#  'cooked': 468,
#  'docked': 468,
#  'bushes': 468,
#  'business': 465,
#  'backpack': 462,
#  'square': 459,
#  'boarding': 459,
#  'low': 458,
#  'assortment': 457,
#  'highway': 457,
#  'wild': 457,
#  'mid': 451,
#  'swimming': 451,
#  'among': 451,
#  'eats': 451,
#  'cabinet': 450,
#  'spoon': 449,
#  'hillside': 449,
#  'jumps': 448,
#  'sunglasses': 447,
#  'wedding': 447,
#  'go': 446,
#  'outdoors': 446,
#  'trail': 446,
#  'wooded': 446,
#  'drawn': 445,
#  'blender': 443,
#  'team': 443,
#  'adults': 440,
#  'controllers': 440,
#  'umpire': 437,
#  'pool': 436,
#  'facing': 434,
#  'van': 433,
#  'clocks': 432,
#  'desktop': 430,
#  'rocky': 426,
#  'trash': 425,
#  'stainless': 425,
#  'lawn': 425,
#  'before': 421,
#  'snowboarding': 421,
#  'toddler': 420,
#  'games': 419,
#  'bun': 419,
#  'foot': 418,
#  'assorted': 417,
#  'snowa': 415,
#  'ice': 413,
#  'hotdog': 413,
#  'broken': 412,
#  'garden': 412,
#  'gamea': 412,
#  'flock': 412,
#  'soup': 411,
#  'kitten': 409,
#  'arms': 408,
#  'landing': 408,
#  'broccoli,': 405,
#  'stairs': 403,
#  'eyes': 403,
#  'flag': 402,
#  'restroom': 401,
#  'phonea': 399,
#  'skating': 398,
#  'stall': 397,
#  'boarda': 396,
#  'things': 396,
#  'see': 396,
#  'table,': 394,
#  'kneeling': 394,
#  'skies': 394,
#  'pointing': 392,
#  'closeup': 391,
#  'arranged': 391,
#  'rackets': 390,
#  'shelves': 389,
#  'electronic': 388,
#  'construction': 387,
#  'ledge': 387,
#  'glove': 387,
#  'gate': 386,
#  'tied': 386,
#  'type': 386,
#  'says': 386,
#  'couches': 386,
#  'graze': 386,
#  'boarder': 384,
#  'tan': 383,
#  'pillow': 383,
#  'does': 382,
#  'overlooking': 381,
#  'kind': 380,
#  'turn': 380,
#  'lunch': 380,
#  'skya': 380,
#  'cups': 379,
#  'coat': 377,
#  'desert': 376,
#  'couch,': 375,
#  'fish': 375,
#  'steps': 375,
#  'wide': 374,
#  'closed': 374,
#  'tomatoes': 374,
#  'rug': 373,
#  'friends': 373,
#  'new': 372,
#  'messy': 372,
#  'potatoes': 371,
#  'trailer': 370,
#  'vegetable': 367,
#  'race': 367,
#  'urban': 366,
#  'land': 366,
#  'event': 366,
#  'hold': 365,
#  'clouds': 364,
#  'doors': 362,
#  'rider': 362,
#  'beda': 362,
#  'bite': 362,
#  'cakes': 361,
#  'courta': 361,
#  'fashioned': 357,
#  'narrow': 357,
#  'appears': 356,
#  'transit': 356,
#  'parka': 356,
#  'picnic': 355,
#  'bottom': 354,
#  'floors': 354,
#  'fighter': 354,
#  'windowa': 353,
#  'loaded': 353,
#  'walla': 352,
#  'ceiling': 352,
#  'gets': 352,
#  'reads': 350,
#  'party': 350,
#  'meat,': 349,
#  'monitors': 349,
#  'himself': 348,
#  'walkway': 348,
#  'tour': 348,
#  'overhead': 347,
#  'fancy': 347,
#  'was': 347,
#  'treea': 346,
#  'pie': 346,
#  'wrapped': 345,
#  'antique': 343,
#  'giving': 343,
#  'short': 343,
#  'gold': 342,
#  'beneath': 341,
#  'pastries': 341,
#  'rest': 341,
#  'petting': 341,
#  'sides': 340,
#  'make': 340,
#  'suits': 340,
#  'action': 340,
#  'held': 339,
#  'object': 339,
#  'contains': 338,
#  'toilets': 338,
#  'kinds': 338,
#  'roof': 337,
#  'curtain': 337,
#  'features': 337,
#  'still': 337,
#  'pants': 337,
#  'signal': 337,
#  'cage': 337,
#  'device': 336,
#  'sunset': 335,
#  'partially': 334,
#  'lies': 333,
#  'photos': 333,
#  'machine': 333,
#  'leather': 333,
#  'leading': 332,
#  'pond': 331,
#  'pots': 330,
#  'towels': 329,
#  'baked': 327,
#  'scooter': 326,
#  'doorway': 326,
#  'togethera': 325,
#  'clothing': 325,
#  'smoke': 325,
#  'steam': 325,
#  'net': 324,
#  'ear': 323,
#  'what': 322,
#  'fooda': 321,
#  'sale': 321,
#  'pepperoni': 321,
#  'prepared': 320,
#  'commuter': 320,
#  'racing': 319,
#  'palm': 318,
#  'shade': 318,
#  'sea': 317,
#  'bed,': 317,
#  'plain': 316,
#  'electric': 316,
#  'winter': 315,
#  'onions': 315,
#  'decorative': 315,
#  'blurry': 314,
#  'structure': 314,
#  'toys': 314,
#  'veggies': 314,
#  'cloth': 313,
#  'pasta': 313,
#  'carrots,': 313,
#  'bow': 311,
#  'pastry': 310,
#  'areaa': 309,
#  ...}

# %%
train_words_count['stove']
# Out:
# 1683

# %%
val_words_count['stove']
# Out:
# 904

# %%
words_count['stove']
# Out:
# 857
